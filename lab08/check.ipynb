# %%
# !python3 ok -q convert_link
# Out:
# =====================================================================
# Assignment: Lab 8
# OK, version v1.18.1
# =====================================================================
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     1 test cases passed! No cases failed.
#
# Performing authentication
# Please enter your school email (.edu):

# %%
# !python3 ok -q every_other
# Out:
# =====================================================================
# Assignment: Lab 8
# OK, version v1.18.1
# =====================================================================
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     1 test cases passed! No cases failed.
#
# Performing authentication
# Please enter your school email (.edu):

# %%
# !python3 ok -q cumulative_mul
# Out:
# =====================================================================
# Assignment: Lab 8
# OK, version v1.18.1
# =====================================================================
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     1 test cases passed! No cases failed.
#
# Performing authentication
# Please enter your school email (.edu):

# %%
# !python3 ok -q has_cycle
# Out:
# =====================================================================
# Assignment: Lab 8
# OK, version v1.18.1
# =====================================================================
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     1 test cases passed! No cases failed.
#
# Performing authentication
# Please enter your school email (.edu):

# %%
# !python3 ok -q has_cycle_constant
# Out:
# =====================================================================
# Assignment: Lab 8
# OK, version v1.18.1
# =====================================================================
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     1 test cases passed! No cases failed.
#
# Performing authentication
# Please enter your school email (.edu):

# %%
# !python3 ok -q reverse_other
# Out:
# =====================================================================
# Assignment: Lab 8
# OK, version v1.18.1
# =====================================================================
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/root/miniconda3/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "ok/__main__.py", line 46, in <module>
#   File "ok/client/cli/ok.py", line 273, in main
#   File "ok/client/protocols/grading.py", line 46, in run
#   File "ok/client/protocols/grading.py", line 62, in grade
#   File "ok/client/sources/doctest/models.py", line 87, in run
#   File "ok/client/sources/common/interpreter.py", line 44, in run
#   File "ok/client/sources/common/interpreter.py", line 217, in interpret
#   File "ok/client/sources/common/interpreter.py", line 275, in _interpret_lines
#   File "ok/client/sources/common/interpreter.py", line 292, in _compare
#   File "/root/lab08/lab08.py", line 245, in __repr__
#     branch_str = ', ' + repr(self.branches)
#   File "/root/lab08/lab08.py", line 248, in __repr__
#     return 'Tree({0}{1})'.format(self.label, branch_str)
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
#   File "/root/lab08/lab08.py", line 256, in __str__
#     return print_tree(self).rstrip()
#   File "/root/lab08/lab08.py", line 252, in print_tree
#     tree_str = '  ' * indent + str(t.label) + "\n"
# RecursionError: maximum recursion depth exceeded while calling a Python object
